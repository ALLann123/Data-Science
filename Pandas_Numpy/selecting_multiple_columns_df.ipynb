# %%
import pandas as pd

# %%
df_exams=pd.read_csv('sample_data/StudentsPerformance.csv')

# %%
#show
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# **1. Selecting two or more columns**

# %%
#selecting 2 or more columns use [[]]
df_exams[['gender','math score']]    #the order of the column is how we want to see it
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
#check the data type
type(df_exams[['gender','math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
#select two or more columns with [[]]
df_exams[['gender',  'writing score','math score', 'reading score']]   #we can change the order here of the column
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# ..      ...            ...         ...            ...
# 995  female             95          88             99
# 996    male             55          62             55
# 997  female             65          59             71
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
#N/B we cant select two or more columns using .
