# %%
import pandas as pd

# %%
#pick the URL we will get the data
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

# %%
tables=pd.read_html(url)     #this returns a list of all tables onthe page

#inspect the first table
df=tables[0]

df
# Out:
#                                 Location  Population % of world         Date  \
# 0                                  World  8232000000       100%  13 Jun 2025
# 1                                  India  1413324000      17.3%   1 Mar 2025
# 2                                  China  1408280000      17.2%  31 Dec 2024
# 3                          United States   340110988       4.2%   1 Jul 2024
# 4                              Indonesia   282477584       3.5%  30 Jun 2024
# ..                                   ...         ...        ...          ...
# 235                   Niue (New Zealand)        1681         0%  11 Nov 2022
# 236                Tokelau (New Zealand)        1647         0%   1 Jan 2019
# 237                         Vatican City         882         0%  31 Dec 2024
# 238  Cocos (Keeling) Islands (Australia)         593         0%  30 Jun 2020
# 239                Pitcairn Islands (UK)          35         0%   1 Jul 2023
#
#     Source (official or from the United Nations) Notes
# 0                            UN projection[1][3]   NaN
# 1                         Official projection[4]   [b]
# 2                           Official estimate[5]   [c]
# 3                           Official estimate[6]   [d]
# 4                  National annual projection[7]   NaN
# ..                                           ...   ...
# 235                             2022 Census[246]   NaN
# 236                             2019 Census[247]   NaN
# 237                         Official figure[248]  [ah]
# 238                             2021 Census[249]   NaN
# 239                       Official estimate[250]   NaN
#
# [240 rows x 6 columns]

# %%
#check the columns
df.columns
# Out:
# Index(['Location', 'Population', '% of world', 'Date',
#        'Source (official or from the United Nations)', 'Notes'],
#       dtype='object')

# %%
#rename the columns
df.columns = ['Country', 'Population', 'World%', 'Date', 'Source', 'Notes']

# %%
df.head(2)
# Out:
#   Country  Population World%         Date                  Source Notes
# 0   World  8232000000   100%  13 Jun 2025     UN projection[1][3]   NaN
# 1   India  1413324000  17.3%   1 Mar 2025  Official projection[4]   [b]

# %%
#clean population and world%
#convert the column values into strings before removing commas and convert to numeric
df['Population']=df['Population'].astype(str).str.replace(',','').astype(int)
df['World%']=df['World%'].astype(str).str.replace("%", '').astype(float)

# %%
df.head(10)
# Out:
#          Country  Population  World%         Date  \
# 0          World  8232000000   100.0  13 Jun 2025
# 1          India  1413324000    17.3   1 Mar 2025
# 2          China  1408280000    17.2  31 Dec 2024
# 3  United States   340110988     4.2   1 Jul 2024
# 4      Indonesia   282477584     3.5  30 Jun 2024
# 5       Pakistan   241499431     3.0   1 Mar 2023
# 6        Nigeria   223800000     2.7   1 Jul 2023
# 7         Brazil   212583750     2.6   1 Jul 2024
# 8     Bangladesh   169828911     2.1  14 Jun 2022
# 9         Russia   146028325     1.8   1 Jan 2025
#
#                           Source Notes
# 0            UN projection[1][3]   NaN
# 1         Official projection[4]   [b]
# 2           Official estimate[5]   [c]
# 3           Official estimate[6]   [d]
# 4  National annual projection[7]   NaN
# 5          2023 census result[8]   [e]
# 6         Official projection[9]   NaN
# 7        Official projection[10]   NaN
# 8         2022 census result[11]   [f]
# 9          Official estimate[13]   [g]

# %%
#drop footnote brackets e.g.[1]
import re

df['Country'] = df['Country'].apply(lambda x: re.sub(r'\[\w+\]', '', x).strip())

# %%
#lets see the cleaned version
df
# Out:
#                                  Country  Population  World%         Date  \
# 0                                  World  8232000000   100.0  13 Jun 2025
# 1                                  India  1413324000    17.3   1 Mar 2025
# 2                                  China  1408280000    17.2  31 Dec 2024
# 3                          United States   340110988     4.2   1 Jul 2024
# 4                              Indonesia   282477584     3.5  30 Jun 2024
# ..                                   ...         ...     ...          ...
# 235                   Niue (New Zealand)        1681     0.0  11 Nov 2022
# 236                Tokelau (New Zealand)        1647     0.0   1 Jan 2019
# 237                         Vatican City         882     0.0  31 Dec 2024
# 238  Cocos (Keeling) Islands (Australia)         593     0.0  30 Jun 2020
# 239                Pitcairn Islands (UK)          35     0.0   1 Jul 2023
#
#                             Source Notes
# 0              UN projection[1][3]   NaN
# 1           Official projection[4]   [b]
# 2             Official estimate[5]   [c]
# 3             Official estimate[6]   [d]
# 4    National annual projection[7]   NaN
# ..                             ...   ...
# 235               2022 Census[246]   NaN
# 236               2019 Census[247]   NaN
# 237           Official figure[248]  [ah]
# 238               2021 Census[249]   NaN
# 239         Official estimate[250]   NaN
#
# [240 rows x 6 columns]

# %%
#lets drop the first column
df.drop(0, inplace=True)

# %%
#show table
df
# Out:
#                                  Country  Population  World%         Date  \
# 1                                  India  1413324000    17.3   1 Mar 2025
# 2                                  China  1408280000    17.2  31 Dec 2024
# 3                          United States   340110988     4.2   1 Jul 2024
# 4                              Indonesia   282477584     3.5  30 Jun 2024
# 5                               Pakistan   241499431     3.0   1 Mar 2023
# ..                                   ...         ...     ...          ...
# 235                   Niue (New Zealand)        1681     0.0  11 Nov 2022
# 236                Tokelau (New Zealand)        1647     0.0   1 Jan 2019
# 237                         Vatican City         882     0.0  31 Dec 2024
# 238  Cocos (Keeling) Islands (Australia)         593     0.0  30 Jun 2020
# 239                Pitcairn Islands (UK)          35     0.0   1 Jul 2023
#
#                             Source Notes
# 1           Official projection[4]   [b]
# 2             Official estimate[5]   [c]
# 3             Official estimate[6]   [d]
# 4    National annual projection[7]   NaN
# 5            2023 census result[8]   [e]
# ..                             ...   ...
# 235               2022 Census[246]   NaN
# 236               2019 Census[247]   NaN
# 237           Official figure[248]  [ah]
# 238               2021 Census[249]   NaN
# 239         Official estimate[250]   NaN
#
# [239 rows x 6 columns]

# %%
df.set_index('Country')
# Out:
#                                      Population  World%         Date  \
# Country
# India                                1413324000    17.3   1 Mar 2025
# China                                1408280000    17.2  31 Dec 2024
# United States                         340110988     4.2   1 Jul 2024
# Indonesia                             282477584     3.5  30 Jun 2024
# Pakistan                              241499431     3.0   1 Mar 2023
# ...                                         ...     ...          ...
# Niue (New Zealand)                         1681     0.0  11 Nov 2022
# Tokelau (New Zealand)                      1647     0.0   1 Jan 2019
# Vatican City                                882     0.0  31 Dec 2024
# Cocos (Keeling) Islands (Australia)         593     0.0  30 Jun 2020
# Pitcairn Islands (UK)                        35     0.0   1 Jul 2023
#
#                                                             Source Notes
# Country
# India                                       Official projection[4]   [b]
# China                                         Official estimate[5]   [c]
# United States                                 Official estimate[6]   [d]
# Indonesia                            National annual projection[7]   NaN
# Pakistan                                     2023 census result[8]   [e]
# ...                                                            ...   ...
# Niue (New Zealand)                                2022 Census[246]   NaN
# Tokelau (New Zealand)                             2019 Census[247]   NaN
# Vatican City                                  Official figure[248]  [ah]
# Cocos (Keeling) Islands (Australia)               2021 Census[249]   NaN
# Pitcairn Islands (UK)                       Official estimate[250]   NaN
#
# [239 rows x 5 columns]

# %%
df
# Out:
#                                  Country  Population  World%         Date  \
# 1                                  India  1413324000    17.3   1 Mar 2025
# 2                                  China  1408280000    17.2  31 Dec 2024
# 3                          United States   340110988     4.2   1 Jul 2024
# 4                              Indonesia   282477584     3.5  30 Jun 2024
# 5                               Pakistan   241499431     3.0   1 Mar 2023
# ..                                   ...         ...     ...          ...
# 235                   Niue (New Zealand)        1681     0.0  11 Nov 2022
# 236                Tokelau (New Zealand)        1647     0.0   1 Jan 2019
# 237                         Vatican City         882     0.0  31 Dec 2024
# 238  Cocos (Keeling) Islands (Australia)         593     0.0  30 Jun 2020
# 239                Pitcairn Islands (UK)          35     0.0   1 Jul 2023
#
#                             Source Notes
# 1           Official projection[4]   [b]
# 2             Official estimate[5]   [c]
# 3             Official estimate[6]   [d]
# 4    National annual projection[7]   NaN
# 5            2023 census result[8]   [e]
# ..                             ...   ...
# 235               2022 Census[246]   NaN
# 236               2019 Census[247]   NaN
# 237           Official figure[248]  [ah]
# 238               2021 Census[249]   NaN
# 239         Official estimate[250]   NaN
#
# [239 rows x 6 columns]

# %%
#find population of Kenya
df[df['Country']=="Kenya"]
# Out:
#    Country  Population  World%        Date                   Source Notes
# 27   Kenya    52428290     0.6  1 Jul 2024  Official projection[31]   NaN

# %%
#lets drop null values
df.dropna(inplace=True)

# %%
#find population for Uganda
df[df['Country'] == "Tanzania"]
# Out:
#      Country  Population  World%        Date                   Source Notes
# 22  Tanzania    66278276     0.8  1 Jul 2024  Official projection[26]   [j]
